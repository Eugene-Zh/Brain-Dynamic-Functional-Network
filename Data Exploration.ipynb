# %%
import numpy as np
import pandas as pd

# %%
data =  pd.read_csv("C:/Users/zyx89/Desktop/研究生/研一/课题/ABCD/abcd_rsfmri_harmonized.csv",sep=' ')

# %%
data
# Out:
#              subjectkey                 eventname site_id_l  \
# 1      NDAR_INV003RTV85     baseline_year_1_arm_1    site06
# 3      NDAR_INV007W6H7B     baseline_year_1_arm_1    site22
# 4      NDAR_INV00BD7VDC     baseline_year_1_arm_1    site07
# 5      NDAR_INV00CY2MDM  2_year_follow_up_y_arm_1    site20
# 6      NDAR_INV00CY2MDM     baseline_year_1_arm_1    site20
# ...                 ...                       ...       ...
# 16833  NDAR_INVZZZ2ALR6  2_year_follow_up_y_arm_1    site08
# 16834  NDAR_INVZZZ2ALR6     baseline_year_1_arm_1    site08
# 16835  NDAR_INVZZZNB0XC     baseline_year_1_arm_1    site03
# 16836  NDAR_INVZZZP87KR  2_year_follow_up_y_arm_1    site19
# 16837  NDAR_INVZZZP87KR     baseline_year_1_arm_1    site19
#
#        rsfmri_c_ngd_ad_ngd_ad  rsfmri_c_ngd_ad_ngd_cgc  \
# 1                    0.439125                 0.218211
# 3                    0.330467                 0.239044
# 4                    0.183244                 0.096860
# ...
